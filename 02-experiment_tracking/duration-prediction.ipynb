# %%
import pandas as pd

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import pickle

# %%
from sklearn.feature_extraction import DictVectorizer
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso

from sklearn.metrics import mean_squared_error

# %%
import mlflow

mlflow.set_tracking_uri("sqlite:///mlflow.db")
mlflow.set_experiment("nyc-taxi-experiment")
# Out:
# <Experiment: artifact_location='/workspaces/mlops-zoomcamp/02-experiment_tracking/mlruns/1', creation_time=1721214263552, experiment_id='1', last_update_time=1721214263552, lifecycle_stage='active', name='nyc-taxi-experiment', tags={}>

# %%
def read_dataframe(filename):
    df = pd.read_parquet(filename)

    df["duration"] = df.lpep_dropoff_datetime - df.lpep_pickup_datetime
    df.duration = df.duration.apply(lambda td: td.total_seconds() / 60)
    df = df[(df.duration >= 1) & (df.duration <= 60)]

    categorical = ['PULocationID', 'DOLocationID']
    df[categorical] = df[categorical].astype(str)
    return df

# %%
df_train = read_dataframe("data/green_tripdata_2021-01.parquet")
df_val = read_dataframe("data/green_tripdata_2021-02.parquet")

# %%
df_train['PU_DO'] = df_train['PULocationID'] + "_" + df_train['DOLocationID']
df_val['PU_DO'] = df_val['PULocationID'] + "_" + df_val['DOLocationID']

# %%
categorical = ["PU_DO"] #['PULocationID', 'DOLocationID']
numerical = ['trip_distance']

dv = DictVectorizer()

train_dicts = df_train[categorical + numerical].to_dict(orient="records")
X_train = dv.fit_transform(train_dicts)

val_dicts = df_val[categorical + numerical].to_dict(orient="records")
X_val = dv.transform(val_dicts)

# %%
target = 'duration'
y_train = df_train[target].values
y_val = df_val[target].values

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)

y_preds = lr.predict(X_val)

mean_squared_error(y_val, y_preds, squared=False)
# Out:
# /home/codespace/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# 7.758715209663881

# %%
with open("models/lin-reg.bin", "wb") as f_out:
    pickle.dump((dv, lr), f_out)

# %%
with mlflow.start_run():

    mlflow.set_tag("developer", "sam")
    
    mlflow.log_param("train-data-path", "data/green_tripdata_2021-01.parquet")
    mlflow.log_param("val-data-path", "data/green_tripdata_2021-02.parquet")

    alpha = 0.1
    mlflow.log_param("alpha", alpha)
    lr = Lasso(alpha)
    lr.fit(X_train, y_train)

    y_preds = lr.predict(X_val)

    rmse = mean_squared_error(y_val, y_preds, squared=False)
    mlflow.log_metric("rmse", rmse)

    mlflow.log_artifact(local_path="models/lin-reg.bin", artifact_path="models_pickle")
# Out:
# /home/codespace/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(

# %% [markdown]
# Experiment Tracking with MLFLow

# %%
import xgboost as xgb

from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
from hyperopt.pyll import scope

# %%
train = xgb.DMatrix(X_train, y_train)
valid = xgb.DMatrix(X_val, y_val)

# %%
def objective(params):
    
    with mlflow.start_run():
        mlflow.set_tag("model", "xgboost")
        mlflow.log_params(params)
        booster = xgb.train(
            params=params,
            dtrain=train,
            num_boost_round=1000,
            evals=[(valid, "validation")],
            early_stopping_rounds=50
        )
        y_pred = booster.predict(valid)
        rmse = mean_squared_error(y_val, y_pred, squared=False)
        mlflow.log_metric("rmse", rmse)

    return {"loss": rmse, "status": STATUS_OK}

# %%
search_space = {
    "max_depth": scope.int(hp.quniform("max_depth", 4, 100, 1)),
    "learning_rate": hp.loguniform("learning_rate", -3, 0),
    "reg_alpha": hp.loguniform("reg_alpha", -5, -1),
    "reg_lambda": hp.loguniform("reg_lambda", -6, -1),
    "min_child_weight": hp.loguniform("min_child_weight", -1, 3),
    "objective": "reg:linear",
    "seed": 42,
}

best_result = fmin(
    fn=objective,
    space=search_space,
    algo=tpe.suggest,
    max_evals=50,
    trials=Trials()
)
# Out:
#   0%|          | 0/50 [00:00<?, ?trial/s, best loss=?]
# /home/codespace/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [11:33:02] WARNING: /workspace/src/objective/regression_obj.cu:227: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)
# [0]	validation-rmse:11.35101
# [1]	validation-rmse:10.61095
# [2]	validation-rmse:9.97736
# [3]	validation-rmse:9.43859
# [4]	validation-rmse:8.98106
# [5]	validation-rmse:8.59677
# [6]	validation-rmse:8.27478
# [7]	validation-rmse:8.00217
# [8]	validation-rmse:7.77389
# [9]	validation-rmse:7.58463
# [10]	validation-rmse:7.42911
# [11]	validation-rmse:7.29590
# [12]	validation-rmse:7.18432
# [13]	validation-rmse:7.09500
# [14]	validation-rmse:7.01815
# [15]	validation-rmse:6.95581
# [16]	validation-rmse:6.89998
# [17]	validation-rmse:6.85578
# [18]	validation-rmse:6.81594
# [19]	validation-rmse:6.78258
# [20]	validation-rmse:6.75512
# [21]	validation-rmse:6.73117
# [22]	validation-rmse:6.70973
# [23]	validation-rmse:6.69174
# [24]	validation-rmse:6.67586
# [25]	validation-rmse:6.66254
# [26]	validation-rmse:6.65058
# [27]	validation-rmse:6.64101
# [28]	validation-rmse:6.63280
# [29]	validation-rmse:6.62461
# [30]	validation-rmse:6.61844
# [31]	validation-rmse:6.61286
# [32]	validation-rmse:6.60773
# [33]	validation-rmse:6.60191
# [34]	validation-rmse:6.59771
# [35]	validation-rmse:6.59329
# [36]	validation-rmse:6.58987
# [37]	validation-rmse:6.58677
# [38]	validation-rmse:6.58430
# [39]	validation-rmse:6.58131
# [40]	validation-rmse:6.57955
# [41]	validation-rmse:6.57740
# [42]	validation-rmse:6.57539
# [43]	validation-rmse:6.57388
# [44]	validation-rmse:6.57167
# [45]	validation-rmse:6.57039
# [46]	validation-rmse:6.56935
# [47]	validation-rmse:6.56835
# [48]	validation-rmse:6.56752
# [49]	validation-rmse:6.56600
# [50]	validation-rmse:6.56502
# [51]	validation-rmse:6.56364
# [52]	validation-rmse:6.56214
# [53]	validation-rmse:6.56114
# [54]	validation-rmse:6.56013
# [55]	validation-rmse:6.55923
# [56]	validation-rmse:6.55832
# [57]	validation-rmse:6.55647
# [58]	validation-rmse:6.55584
# [59]	validation-rmse:6.55496
# [60]	validation-rmse:6.55415
# [61]	validation-rmse:6.55324
# [62]	validation-rmse:6.55203
# [63]	validation-rmse:6.55161
# [64]	validation-rmse:6.55060
# [65]	validation-rmse:6.55011
# [66]	validation-rmse:6.54949
# [67]	validation-rmse:6.54872
# [68]	validation-rmse:6.54800
# [69]	validation-rmse:6.54717
# [70]	validation-rmse:6.54648
# [71]	validation-rmse:6.54580
# [72]	validation-rmse:6.54517
# [73]	validation-rmse:6.54442
# [74]	validation-rmse:6.54337
# [75]	validation-rmse:6.54276
# [76]	validation-rmse:6.54183
# [77]	validation-rmse:6.54106
# [78]	validation-rmse:6.54060
# [79]	validation-rmse:6.54017
# [80]	validation-rmse:6.53962
# [81]	validation-rmse:6.53852
# [82]	validation-rmse:6.53819
# [83]	validation-rmse:6.53768
# [84]	validation-rmse:6.53680
# [85]	validation-rmse:6.53580
# [86]	validation-rmse:6.53519
# [87]	validation-rmse:6.53476
# [88]	validation-rmse:6.53385
# [89]	validation-rmse:6.53338
# [90]	validation-rmse:6.53297
# [91]	validation-rmse:6.53228
# [92]	validation-rmse:6.53156
# [93]	validation-rmse:6.53106
# [94]	validation-rmse:6.53058
# [95]	validation-rmse:6.53008
# [96]	validation-rmse:6.52940
# [97]	validation-rmse:6.52918
# [98]	validation-rmse:6.52848
# [99]	validation-rmse:6.52853
# [100]	validation-rmse:6.52793
# [101]	validation-rmse:6.52729
# [102]	validation-rmse:6.52672
# [103]	validation-rmse:6.52604
# [104]	validation-rmse:6.52570
# [105]	validation-rmse:6.52548
# [106]	validation-rmse:6.52450
# [107]	validation-rmse:6.52425
# [108]	validation-rmse:6.52372
# [109]	validation-rmse:6.52312
# [110]	validation-rmse:6.52276
# [111]	validation-rmse:6.52223
# [112]	validation-rmse:6.52161
# [113]	validation-rmse:6.52129
# [114]	validation-rmse:6.52077
# [115]	validation-rmse:6.52053
# [116]	validation-rmse:6.51977
# [117]	validation-rmse:6.51906
# [118]	validation-rmse:6.51832
# [119]	validation-rmse:6.51756
# [120]	validation-rmse:6.51724
# [121]	validation-rmse:6.51682
# [122]	validation-rmse:6.51611
# [123]	validation-rmse:6.51548
# [124]	validation-rmse:6.51486
# [125]	validation-rmse:6.51460
# [126]	validation-rmse:6.51420
# [127]	validation-rmse:6.51380
# [128]	validation-rmse:6.51347
# [129]	validation-rmse:6.51305
# [130]	validation-rmse:6.51232
# [131]	validation-rmse:6.51166
# [132]	validation-rmse:6.51123
# [133]	validation-rmse:6.51085
# [134]	validation-rmse:6.51076
# [135]	validation-rmse:6.51058
# [136]	validation-rmse:6.50986
# [137]	validation-rmse:6.50922
# [138]	validation-rmse:6.50898
# [139]	validation-rmse:6.50865
# [140]	validation-rmse:6.50782
# [141]	validation-rmse:6.50755
# [142]	validation-rmse:6.50693
# [143]	validation-rmse:6.50583
# [144]	validation-rmse:6.50541
# [145]	validation-rmse:6.50545
# [146]	validation-rmse:6.50492
# [147]	validation-rmse:6.50417
# [148]	validation-rmse:6.50377
# [149]	validation-rmse:6.50342
# [150]	validation-rmse:6.50313
# [151]	validation-rmse:6.50280
# [152]	validation-rmse:6.50245
# [153]	validation-rmse:6.50177
# [154]	validation-rmse:6.50149
# [155]	validation-rmse:6.50086
# [156]	validation-rmse:6.50072
# [157]	validation-rmse:6.50051
# [158]	validation-rmse:6.50033
# [159]	validation-rmse:6.50004
# [160]	validation-rmse:6.49973
# [161]	validation-rmse:6.49970
# [162]	validation-rmse:6.49902
# [163]	validation-rmse:6.49880
# [164]	validation-rmse:6.49834
# [165]	validation-rmse:6.49762
# [166]	validation-rmse:6.49763
# [167]	validation-rmse:6.49704
# [168]	validation-rmse:6.49669
# [169]	validation-rmse:6.49626
# [170]	validation-rmse:6.49595
# [171]	validation-rmse:6.49544
# [172]	validation-rmse:6.49525
# [173]	validation-rmse:6.49475
# [174]	validation-rmse:6.49415
# [175]	validation-rmse:6.49377
# [176]	validation-rmse:6.49316
# [177]	validation-rmse:6.49295
# [178]	validation-rmse:6.49272
# [179]	validation-rmse:6.49244
# [180]	validation-rmse:6.49226
# [181]	validation-rmse:6.49189
# [182]	validation-rmse:6.49162
# [183]	validation-rmse:6.49082
# [184]	validation-rmse:6.49052
# [185]	validation-rmse:6.49034
# [186]	validation-rmse:6.48990
# [187]	validation-rmse:6.48962
# [188]	validation-rmse:6.48892
# [189]	validation-rmse:6.48869
# [190]	validation-rmse:6.48846
# [191]	validation-rmse:6.48804
# [192]	validation-rmse:6.48785
# [193]	validation-rmse:6.48713
# [194]	validation-rmse:6.48668
# [195]	validation-rmse:6.48633
# [196]	validation-rmse:6.48626
# [197]	validation-rmse:6.48552
# [198]	validation-rmse:6.48518
# [199]	validation-rmse:6.48514
# [200]	validation-rmse:6.48462
# [201]	validation-rmse:6.48423
# [202]	validation-rmse:6.48384
# [203]	validation-rmse:6.48353
# [204]	validation-rmse:6.48308
# [205]	validation-rmse:6.48292
# [206]	validation-rmse:6.48290
# [207]	validation-rmse:6.48281
# [208]	validation-rmse:6.48242
# [209]	validation-rmse:6.48192
# [210]	validation-rmse:6.48168
# [211]	validation-rmse:6.48161
# [212]	validation-rmse:6.48139
# [213]	validation-rmse:6.48110
# [214]	validation-rmse:6.48068
# [215]	validation-rmse:6.48033
# [216]	validation-rmse:6.48018
# [217]	validation-rmse:6.47990
# [218]	validation-rmse:6.47969
# [219]	validation-rmse:6.47915
# [220]	validation-rmse:6.47876
# [221]	validation-rmse:6.47849
# [222]	validation-rmse:6.47835
# [223]	validation-rmse:6.47825
# [224]	validation-rmse:6.47796
# [225]	validation-rmse:6.47798
# [226]	validation-rmse:6.47781
# [227]	validation-rmse:6.47716
# [228]	validation-rmse:6.47686
# [229]	validation-rmse:6.47666
# [230]	validation-rmse:6.47636
# [231]	validation-rmse:6.47596
# [232]	validation-rmse:6.47567
# [233]	validation-rmse:6.47536
# [234]	validation-rmse:6.47506
# [235]	validation-rmse:6.47469
# [236]	validation-rmse:6.47434
# [237]	validation-rmse:6.47369
# [238]	validation-rmse:6.47362
# [239]	validation-rmse:6.47333
# [240]	validation-rmse:6.47314
# [241]	validation-rmse:6.47287
# [242]	validation-rmse:6.47302
# [243]	validation-rmse:6.47292
# [244]	validation-rmse:6.47237
# [245]	validation-rmse:6.47195
# [246]	validation-rmse:6.47149
# [247]	validation-rmse:6.47111
# [248]	validation-rmse:6.47091
# [249]	validation-rmse:6.47078
# [250]	validation-rmse:6.47047
# [251]	validation-rmse:6.47005
# [252]	validation-rmse:6.46992
# [253]	validation-rmse:6.46989
# [254]	validation-rmse:6.46963
# [255]	validation-rmse:6.46943
# [256]	validation-rmse:6.46918
# [257]	validation-rmse:6.46859
# [258]	validation-rmse:6.46830
# [259]	validation-rmse:6.46816
# [260]	validation-rmse:6.46817
# [261]	validation-rmse:6.46761
# [262]	validation-rmse:6.46768
# [263]	validation-rmse:6.46740
# [264]	validation-rmse:6.46721
# [265]	validation-rmse:6.46707
# [266]	validation-rmse:6.46693
# [267]	validation-rmse:6.46661
# [268]	validation-rmse:6.46637
# [269]	validation-rmse:6.46621
# [270]	validation-rmse:6.46590
# [271]	validation-rmse:6.46529
# [272]	validation-rmse:6.46506
# [273]	validation-rmse:6.46461
# [274]	validation-rmse:6.46485
# [275]	validation-rmse:6.46458
# [276]	validation-rmse:6.46446
# [277]	validation-rmse:6.46419
# [278]	validation-rmse:6.46378
# [279]	validation-rmse:6.46333
# [280]	validation-rmse:6.46316
# [281]	validation-rmse:6.46314
# [282]	validation-rmse:6.46280
# [283]	validation-rmse:6.46273
# [284]	validation-rmse:6.46220
# [285]	validation-rmse:6.46197
# [286]	validation-rmse:6.46158
# [287]	validation-rmse:6.46134
# [288]	validation-rmse:6.46086
# [289]	validation-rmse:6.46065
# [290]	validation-rmse:6.46013
# [291]	validation-rmse:6.46005
# [292]	validation-rmse:6.45984
# [293]	validation-rmse:6.45971
# [294]	validation-rmse:6.45936
# [295]	validation-rmse:6.45910
# [296]	validation-rmse:6.45902
# [297]	validation-rmse:6.45884
# [298]	validation-rmse:6.45866
# [299]	validation-rmse:6.45896
# [300]	validation-rmse:6.45853
# [301]	validation-rmse:6.45799
# [302]	validation-rmse:6.45794
# [303]	validation-rmse:6.45785
# [304]	validation-rmse:6.45754
# [305]	validation-rmse:6.45736
# [306]	validation-rmse:6.45714
# [307]	validation-rmse:6.45699
# [308]	validation-rmse:6.45706
# [309]	validation-rmse:6.45681
# [310]	validation-rmse:6.45638
# [311]	validation-rmse:6.45629
# [312]	validation-rmse:6.45614
# [313]	validation-rmse:6.45618
# [314]	validation-rmse:6.45575
# [315]	validation-rmse:6.45538
# [316]	validation-rmse:6.45534
# [317]	validation-rmse:6.45506
# [318]	validation-rmse:6.45497
# [319]	validation-rmse:6.45472
# [320]	validation-rmse:6.45438
# [321]	validation-rmse:6.45418
# [322]	validation-rmse:6.45397
# [323]	validation-rmse:6.45389
# [324]	validation-rmse:6.45377
# [325]	validation-rmse:6.45355
# [326]	validation-rmse:6.45348
# [327]	validation-rmse:6.45329
# [328]	validation-rmse:6.45295
# [329]	validation-rmse:6.45288
# [330]	validation-rmse:6.45259
# [331]	validation-rmse:6.45264
# [332]	validation-rmse:6.45282
# [333]	validation-rmse:6.45265
# [334]	validation-rmse:6.45238
# [335]	validation-rmse:6.45211
# [336]	validation-rmse:6.45217
# [337]	validation-rmse:6.45203
# [338]	validation-rmse:6.45165
# [339]	validation-rmse:6.45137
# [340]	validation-rmse:6.45116
# [341]	validation-rmse:6.45083
# [342]	validation-rmse:6.45064
# [343]	validation-rmse:6.45030
# [344]	validation-rmse:6.45015
# [345]	validation-rmse:6.45003
# [346]	validation-rmse:6.45013
# [347]	validation-rmse:6.44993
# [348]	validation-rmse:6.44968
# [349]	validation-rmse:6.44921
# [350]	validation-rmse:6.44896
# [351]	validation-rmse:6.44851
# [352]	validation-rmse:6.44837
# [353]	validation-rmse:6.44831
# [354]	validation-rmse:6.44826
# [355]	validation-rmse:6.44797
# [356]	validation-rmse:6.44779
# [357]	validation-rmse:6.44765
# [358]	validation-rmse:6.44724
# [359]	validation-rmse:6.44696
# [360]	validation-rmse:6.44698
# [361]	validation-rmse:6.44734
# [362]	validation-rmse:6.44722
# [363]	validation-rmse:6.44694
# [364]	validation-rmse:6.44669
# [365]	validation-rmse:6.44648
# [366]	validation-rmse:6.44621
# [367]	validation-rmse:6.44548
# [368]	validation-rmse:6.44537
# [369]	validation-rmse:6.44552
# [370]	validation-rmse:6.44534
# [371]	validation-rmse:6.44524
# [372]	validation-rmse:6.44501
# [373]	validation-rmse:6.44499
# [374]	validation-rmse:6.44470
# [375]	validation-rmse:6.44445
# [376]	validation-rmse:6.44423
# [377]	validation-rmse:6.44351
# [378]	validation-rmse:6.44353
# [379]	validation-rmse:6.44327
# [380]	validation-rmse:6.44322
# [381]	validation-rmse:6.44256
# [382]	validation-rmse:6.44250
# [383]	validation-rmse:6.44219
# [384]	validation-rmse:6.44248
# [385]	validation-rmse:6.44232
# [386]	validation-rmse:6.44199
# [387]	validation-rmse:6.44161
# [388]	validation-rmse:6.44152
# [389]	validation-rmse:6.44127
# [390]	validation-rmse:6.44119
# [391]	validation-rmse:6.44106
# [392]	validation-rmse:6.44071
# [393]	validation-rmse:6.44073
# [394]	validation-rmse:6.44047
# [395]	validation-rmse:6.43972
# [396]	validation-rmse:6.43964
# [397]	validation-rmse:6.43962
# [398]	validation-rmse:6.43940
# [399]	validation-rmse:6.43927
# [400]	validation-rmse:6.43898
# [401]	validation-rmse:6.43851
# [402]	validation-rmse:6.43842
# [403]	validation-rmse:6.43810
# [404]	validation-rmse:6.43812
# [405]	validation-rmse:6.43805
# [406]	validation-rmse:6.43786
# [407]	validation-rmse:6.43775
# [408]	validation-rmse:6.43762
# [409]	validation-rmse:6.43747
# [410]	validation-rmse:6.43735
# [411]	validation-rmse:6.43719
# [412]	validation-rmse:6.43708
# [413]	validation-rmse:6.43707
# [414]	validation-rmse:6.43686
# [415]	validation-rmse:6.43704
# [416]	validation-rmse:6.43739
# [417]	validation-rmse:6.43725
# [418]	validation-rmse:6.43691
# [419]	validation-rmse:6.43699
# [420]	validation-rmse:6.43707
# [421]	validation-rmse:6.43691
# [422]	validation-rmse:6.43689
# [423]	validation-rmse:6.43670
# [424]	validation-rmse:6.43669
# [425]	validation-rmse:6.43640
# [426]	validation-rmse:6.43637
# [427]	validation-rmse:6.43623
# [428]	validation-rmse:6.43584
# [429]	validation-rmse:6.43583
# [430]	validation-rmse:6.43592
# [431]	validation-rmse:6.43575
# [432]	validation-rmse:6.43557
# [433]	validation-rmse:6.43549
# [434]	validation-rmse:6.43537
# [435]	validation-rmse:6.43496
# [436]	validation-rmse:6.43492
# [437]	validation-rmse:6.43465
# [438]	validation-rmse:6.43435
# [439]	validation-rmse:6.43448
# [440]	validation-rmse:6.43428
# [441]	validation-rmse:6.43419
# [442]	validation-rmse:6.43439
# [443]	validation-rmse:6.43441
# [444]	validation-rmse:6.43453
# [445]	validation-rmse:6.43435
# [446]	validation-rmse:6.43404
# [447]	validation-rmse:6.43411
# [448]	validation-rmse:6.43373
# [449]	validation-rmse:6.43382
# [450]	validation-rmse:6.43374
# [451]	validation-rmse:6.43382
# [452]	validation-rmse:6.43378
# [453]	validation-rmse:6.43373
# [454]	validation-rmse:6.43369
# [455]	validation-rmse:6.43360
# [456]	validation-rmse:6.43341
# [457]	validation-rmse:6.43320
# [458]	validation-rmse:6.43264
# [459]	validation-rmse:6.43243
# [460]	validation-rmse:6.43228
# [461]	validation-rmse:6.43235
# [462]	validation-rmse:6.43224
# [463]	validation-rmse:6.43209
# [464]	validation-rmse:6.43201
# [465]	validation-rmse:6.43190
# [466]	validation-rmse:6.43168
# [467]	validation-rmse:6.43142
# [468]	validation-rmse:6.43126
# [469]	validation-rmse:6.43122
# [470]	validation-rmse:6.43060
# [471]	validation-rmse:6.43052
# [472]	validation-rmse:6.43010
# [473]	validation-rmse:6.43006
# [474]	validation-rmse:6.43000
# [475]	validation-rmse:6.42990
# [476]	validation-rmse:6.42960
# [477]	validation-rmse:6.42942
# [478]	validation-rmse:6.42941
# [479]	validation-rmse:6.42924
# [480]	validation-rmse:6.42937
# [481]	validation-rmse:6.42931
# [482]	validation-rmse:6.42917
# [483]	validation-rmse:6.42912
# [484]	validation-rmse:6.42900
# [485]	validation-rmse:6.42888
# [486]	validation-rmse:6.42870
# [487]	validation-rmse:6.42850
# [488]	validation-rmse:6.42851
# [489]	validation-rmse:6.42838
# [490]	validation-rmse:6.42839
# [491]	validation-rmse:6.42805
# [492]	validation-rmse:6.42789
# [493]	validation-rmse:6.42766
# [494]	validation-rmse:6.42787
# [495]	validation-rmse:6.42795
# [496]	validation-rmse:6.42788
# [497]	validation-rmse:6.42771
# [498]	validation-rmse:6.42756
# [499]	validation-rmse:6.42741
# [500]	validation-rmse:6.42654
# [501]	validation-rmse:6.42646
# [502]	validation-rmse:6.42622
# [503]	validation-rmse:6.42607
# [504]	validation-rmse:6.42609
# [505]	validation-rmse:6.42574
# [506]	validation-rmse:6.42557
# [507]	validation-rmse:6.42544
# [508]	validation-rmse:6.42507
# [509]	validation-rmse:6.42465
# [510]	validation-rmse:6.42433
# [511]	validation-rmse:6.42422
# [512]	validation-rmse:6.42406
# [513]	validation-rmse:6.42387
# [514]	validation-rmse:6.42378
# [515]	validation-rmse:6.42347
# [516]	validation-rmse:6.42345
# [517]	validation-rmse:6.42324
# [518]	validation-rmse:6.42318
# [519]	validation-rmse:6.42325
# [520]	validation-rmse:6.42320
# [521]	validation-rmse:6.42314
# [522]	validation-rmse:6.42302
# [523]	validation-rmse:6.42272
# [524]	validation-rmse:6.42253
# [525]	validation-rmse:6.42249
# [526]	validation-rmse:6.42256
# [527]	validation-rmse:6.42240
# [528]	validation-rmse:6.42190
# [529]	validation-rmse:6.42194
# [530]	validation-rmse:6.42233
# [531]	validation-rmse:6.42214
# [532]	validation-rmse:6.42209
# [533]	validation-rmse:6.42187
# [534]	validation-rmse:6.42192
# [535]	validation-rmse:6.42202
# [536]	validation-rmse:6.42199
# [537]	validation-rmse:6.42199
# [538]	validation-rmse:6.42194
# [539]	validation-rmse:6.42171
# [540]	validation-rmse:6.42166
# [541]	validation-rmse:6.42144
# [542]	validation-rmse:6.42154
# [543]	validation-rmse:6.42148
# [544]	validation-rmse:6.42139
# [545]	validation-rmse:6.42119
# [546]	validation-rmse:6.42106
# [547]	validation-rmse:6.42086
# [548]	validation-rmse:6.42092
# [549]	validation-rmse:6.42082
# [550]	validation-rmse:6.42069
# [551]	validation-rmse:6.42071
# [552]	validation-rmse:6.42070
# [553]	validation-rmse:6.42068
# [554]	validation-rmse:6.42042
# [555]	validation-rmse:6.42026
# [556]	validation-rmse:6.42044
# [557]	validation-rmse:6.42009
# [558]	validation-rmse:6.42022
# [559]	validation-rmse:6.42008
# [560]	validation-rmse:6.41987
# [561]	validation-rmse:6.41989
# [562]	validation-rmse:6.41985
# [563]	validation-rmse:6.41973
# [564]	validation-rmse:6.41953
# [565]	validation-rmse:6.41936
# [566]	validation-rmse:6.41933
# [567]	validation-rmse:6.41932
# [568]	validation-rmse:6.41911
# [569]	validation-rmse:6.41897
# [570]	validation-rmse:6.41882
# [571]	validation-rmse:6.41862
# [572]	validation-rmse:6.41852
# [573]	validation-rmse:6.41847
# [574]	validation-rmse:6.41846
# [575]	validation-rmse:6.41836
# [576]	validation-rmse:6.41866
# [577]	validation-rmse:6.41852
# [578]	validation-rmse:6.41876
# [579]	validation-rmse:6.41873
# [580]	validation-rmse:6.41870
# [581]	validation-rmse:6.41876
# [582]	validation-rmse:6.41910
# [583]	validation-rmse:6.41895
# [584]	validation-rmse:6.41889
# [585]	validation-rmse:6.41870
# [586]	validation-rmse:6.41845
# [587]	validation-rmse:6.41830
# [588]	validation-rmse:6.41822
# [589]	validation-rmse:6.41827
# [590]	validation-rmse:6.41802
# [591]	validation-rmse:6.41795
# [592]	validation-rmse:6.41789
# [593]	validation-rmse:6.41771
# [594]	validation-rmse:6.41764
# [595]	validation-rmse:6.41758
# [596]	validation-rmse:6.41739
# [597]	validation-rmse:6.41730
# [598]	validation-rmse:6.41703
# [599]	validation-rmse:6.41700
# [600]	validation-rmse:6.41705
# [601]	validation-rmse:6.41700
# [602]	validation-rmse:6.41689
# [603]	validation-rmse:6.41700
# [604]	validation-rmse:6.41638
# [605]	validation-rmse:6.41619
# [606]	validation-rmse:6.41591
# [607]	validation-rmse:6.41551
# [608]	validation-rmse:6.41532
# [609]	validation-rmse:6.41522
# [610]	validation-rmse:6.41492
# [611]	validation-rmse:6.41477
# [612]	validation-rmse:6.41454
# [613]	validation-rmse:6.41463
# [614]	validation-rmse:6.41465
# [615]	validation-rmse:6.41452
# [616]	validation-rmse:6.41452
# [617]	validation-rmse:6.41449
# [618]	validation-rmse:6.41457
# [619]	validation-rmse:6.41453
# [620]	validation-rmse:6.41461
# [621]	validation-rmse:6.41442
# [622]	validation-rmse:6.41441
# [623]	validation-rmse:6.41429
# [624]	validation-rmse:6.41418
# [625]	validation-rmse:6.41395
# [626]	validation-rmse:6.41384
# [627]	validation-rmse:6.41369
# [628]	validation-rmse:6.41386
# [629]	validation-rmse:6.41385
# [630]	validation-rmse:6.41391
# [631]	validation-rmse:6.41375
# [632]	validation-rmse:6.41369
# [633]	validation-rmse:6.41351
# [634]	validation-rmse:6.41342
# [635]	validation-rmse:6.41333
# [636]	validation-rmse:6.41312
# [637]	validation-rmse:6.41295
# [638]	validation-rmse:6.41353
# [639]	validation-rmse:6.41338
# [640]	validation-rmse:6.41249
# [641]	validation-rmse:6.41228
# [642]	validation-rmse:6.41213
# [643]	validation-rmse:6.41222
# [644]	validation-rmse:6.41187
# [645]	validation-rmse:6.41163
# [646]	validation-rmse:6.41152
# [647]	validation-rmse:6.41169
# [648]	validation-rmse:6.41162
# [649]	validation-rmse:6.41145
# [650]	validation-rmse:6.41116
# [651]	validation-rmse:6.41098
# [652]	validation-rmse:6.41092
# [653]	validation-rmse:6.41131
# [654]	validation-rmse:6.41140
# [655]	validation-rmse:6.41126
# [656]	validation-rmse:6.41102
# [657]	validation-rmse:6.41097
# [658]	validation-rmse:6.41077
# [659]	validation-rmse:6.41070
# [660]	validation-rmse:6.41042
# [661]	validation-rmse:6.41026
# [662]	validation-rmse:6.41024
# [663]	validation-rmse:6.41006
# [664]	validation-rmse:6.41003
# [665]	validation-rmse:6.41001
# [666]	validation-rmse:6.41017
# [667]	validation-rmse:6.41031
# [668]	validation-rmse:6.41023
# [669]	validation-rmse:6.41012
# [670]	validation-rmse:6.40997
# [671]	validation-rmse:6.40992
# [672]	validation-rmse:6.40992
# [673]	validation-rmse:6.40990
# [674]	validation-rmse:6.40979
# [675]	validation-rmse:6.40979
# [676]	validation-rmse:6.40967
# [677]	validation-rmse:6.40978
# [678]	validation-rmse:6.40962
# [679]	validation-rmse:6.40955
# [680]	validation-rmse:6.40929
# [681]	validation-rmse:6.40934
# [682]	validation-rmse:6.40917
# [683]	validation-rmse:6.40928
# [684]	validation-rmse:6.40914
# [685]	validation-rmse:6.40917
# [686]	validation-rmse:6.40904
# [687]	validation-rmse:6.40924
# [688]	validation-rmse:6.40912
# [689]	validation-rmse:6.40898
# [690]	validation-rmse:6.40905
# [691]	validation-rmse:6.40904
# [692]	validation-rmse:6.40898
# [693]	validation-rmse:6.40889
# [694]	validation-rmse:6.40883
# [695]	validation-rmse:6.40872
# [696]	validation-rmse:6.40856
# [697]	validation-rmse:6.40860
# [698]	validation-rmse:6.40849
# [699]	validation-rmse:6.40841
# [700]	validation-rmse:6.40890
# [701]	validation-rmse:6.40923
# [702]	validation-rmse:6.40923
# [703]	validation-rmse:6.40899
# [704]	validation-rmse:6.40899
# [705]	validation-rmse:6.40894
# [706]	validation-rmse:6.40891
# [707]	validation-rmse:6.40873
# [708]	validation-rmse:6.40864
# [709]	validation-rmse:6.40864
# [710]	validation-rmse:6.40843
# [711]	validation-rmse:6.40836
# [712]	validation-rmse:6.40830
# [713]	validation-rmse:6.40825
# [714]	validation-rmse:6.40820
# [715]	validation-rmse:6.40795
# [716]	validation-rmse:6.40789
# [717]	validation-rmse:6.40794
# [718]	validation-rmse:6.40785
# [719]	validation-rmse:6.40787
# [720]	validation-rmse:6.40786
# [721]	validation-rmse:6.40773
# [722]	validation-rmse:6.40757
# [723]	validation-rmse:6.40756
# [724]	validation-rmse:6.40743
# [725]	validation-rmse:6.40727
# [726]	validation-rmse:6.40711
# [727]	validation-rmse:6.40697
# [728]	validation-rmse:6.40689
# [729]	validation-rmse:6.40685
# [730]	validation-rmse:6.40682
# [731]	validation-rmse:6.40678
# [732]	validation-rmse:6.40670
# [733]	validation-rmse:6.40657
# [734]	validation-rmse:6.40672
# [735]	validation-rmse:6.40664
# [736]	validation-rmse:6.40663
# [737]	validation-rmse:6.40725
# [738]	validation-rmse:6.40731
# [739]	validation-rmse:6.40721
# [740]	validation-rmse:6.40704
# [741]	validation-rmse:6.40708
# [742]	validation-rmse:6.40688
# [743]	validation-rmse:6.40686
# [744]	validation-rmse:6.40677
# [745]	validation-rmse:6.40671
# [746]	validation-rmse:6.40660
# [747]	validation-rmse:6.40659
# [748]	validation-rmse:6.40663
# [749]	validation-rmse:6.40636
# [750]	validation-rmse:6.40639
# [751]	validation-rmse:6.40640
# [752]	validation-rmse:6.40633
# [753]	validation-rmse:6.40534
# [754]	validation-rmse:6.40528
# [755]	validation-rmse:6.40517
# [756]	validation-rmse:6.40506
# [757]	validation-rmse:6.40498
# [758]	validation-rmse:6.40474
# [759]	validation-rmse:6.40454
# [760]	validation-rmse:6.40452
# [761]	validation-rmse:6.40449
# [762]	validation-rmse:6.40459
# [763]	validation-rmse:6.40455
# [764]	validation-rmse:6.40427
# [765]	validation-rmse:6.40415
# [766]	validation-rmse:6.40421
# [767]	validation-rmse:6.40405
# [768]	validation-rmse:6.40371
# [769]	validation-rmse:6.40378
# [770]	validation-rmse:6.40375
# [771]	validation-rmse:6.40364
# [772]	validation-rmse:6.40340
# [773]	validation-rmse:6.40339
# [774]	validation-rmse:6.40337
# [775]	validation-rmse:6.40324
# [776]	validation-rmse:6.40320
# [777]	validation-rmse:6.40320
# [778]	validation-rmse:6.40330
# [779]	validation-rmse:6.40339
# [780]	validation-rmse:6.40339
# [781]	validation-rmse:6.40328
# [782]	validation-rmse:6.40324
# [783]	validation-rmse:6.40322
# [784]	validation-rmse:6.40338
# [785]	validation-rmse:6.40318
# [786]	validation-rmse:6.40336
# [787]	validation-rmse:6.40337
# [788]	validation-rmse:6.40325
# [789]	validation-rmse:6.40323
# [790]	validation-rmse:6.40314
# [791]	validation-rmse:6.40319
# [792]	validation-rmse:6.40304
# [793]	validation-rmse:6.40333
# [794]	validation-rmse:6.40319
# [795]	validation-rmse:6.40308
# [796]	validation-rmse:6.40311
# [797]	validation-rmse:6.40294
# [798]	validation-rmse:6.40279
# [799]	validation-rmse:6.40277
# [800]	validation-rmse:6.40263
# [801]	validation-rmse:6.40251
# [802]	validation-rmse:6.40245
# [803]	validation-rmse:6.40235
# [804]	validation-rmse:6.40227
# [805]	validation-rmse:6.40211
# [806]	validation-rmse:6.40211
# [807]	validation-rmse:6.40206
# [808]	validation-rmse:6.40193
# [809]	validation-rmse:6.40185
# [810]	validation-rmse:6.40175
# [811]	validation-rmse:6.40161
# [812]	validation-rmse:6.40155
# [813]	validation-rmse:6.40141
# [814]	validation-rmse:6.40147
# [815]	validation-rmse:6.40140
# [816]	validation-rmse:6.40155
# [817]	validation-rmse:6.40175
# [818]	validation-rmse:6.40161
# [819]	validation-rmse:6.40141
# [820]	validation-rmse:6.40143
# [821]	validation-rmse:6.40149
# [822]	validation-rmse:6.40134
# [823]	validation-rmse:6.40127
# [824]	validation-rmse:6.40122
# [825]	validation-rmse:6.40129
# [826]	validation-rmse:6.40117
# [827]	validation-rmse:6.40122
# [828]	validation-rmse:6.40101
# [829]	validation-rmse:6.40059
# [830]	validation-rmse:6.40074
# [831]	validation-rmse:6.40067
# [832]	validation-rmse:6.40072
# [833]	validation-rmse:6.40079
# [834]	validation-rmse:6.40066
# [835]	validation-rmse:6.40056
# [836]	validation-rmse:6.40052
# [837]	validation-rmse:6.40052
# [838]	validation-rmse:6.40043
# [839]	validation-rmse:6.40047
# [840]	validation-rmse:6.40041
# [841]	validation-rmse:6.40028
# [842]	validation-rmse:6.40028
# [843]	validation-rmse:6.40033
# [844]	validation-rmse:6.40054
# [845]	validation-rmse:6.40058
# [846]	validation-rmse:6.40076
# [847]	validation-rmse:6.40092
# [848]	validation-rmse:6.40124
# [849]	validation-rmse:6.40110
# [850]	validation-rmse:6.40100
# [851]	validation-rmse:6.40094
# [852]	validation-rmse:6.40087
# [853]	validation-rmse:6.40079
# [854]	validation-rmse:6.40075
# [855]	validation-rmse:6.40081
# [856]	validation-rmse:6.40075
# [857]	validation-rmse:6.40079
# [858]	validation-rmse:6.40104
# [859]	validation-rmse:6.40106
# [860]	validation-rmse:6.40101
# [861]	validation-rmse:6.40095
# [862]	validation-rmse:6.40076
# [863]	validation-rmse:6.40072
# [864]	validation-rmse:6.40067
# [865]	validation-rmse:6.40059
# ...
# [498]	validation-rmse:6.42622
# [499]	validation-rmse:6.42623
# [500]	validation-rmse:6.42622
# [501]	validation-rmse:6.42623
# [502]	validation-rmse:6.42613
# [503]	validation-rmse:6.42597
# [504]	validation-rmse:6.42562
# [505]	validation-rmse:6.42559
# [506]	validation-rmse:6.42548
# [507]	validation-rmse:6.42538
# [508]	validation-rmse:6.42502
# [509]	validation-rmse:6.42491
# [510]	validation-rmse:6.42480
# [511]	validation-rmse:6.42480
# [512]	validation-rmse:6.42463
# [513]	validation-rmse:6.42461
# [514]	validation-rmse:6.42458
# [515]	validation-rmse:6.42454
# [516]	validation-rmse:6.42445
# [517]	validation-rmse:6.42445
# [518]	validation-rmse:6.42448
# [519]	validation-rmse:6.42442
# [520]	validation-rmse:6.42445
# [521]	validation-rmse:6.42451
# [522]	validation-rmse:6.42421
# [523]	validation-rmse:6.42394
# [524]	validation-rmse:6.42379
# [525]	validation-rmse:6.42372
# [526]	validation-rmse:6.42345
# [527]	validation-rmse:6.42339
# [528]	validation-rmse:6.42334
# [529]	validation-rmse:6.42326
# [530]	validation-rmse:6.42306
# [531]	validation-rmse:6.42295
# [532]	validation-rmse:6.42285
# [533]	validation-rmse:6.42277
# [534]	validation-rmse:6.42259
# [535]	validation-rmse:6.42259
# [536]	validation-rmse:6.42240
# [537]	validation-rmse:6.42228
# [538]	validation-rmse:6.42224
# [539]	validation-rmse:6.42225
# [540]	validation-rmse:6.42187
# [541]	validation-rmse:6.42184
# [542]	validation-rmse:6.42180
# [543]	validation-rmse:6.42172
# [544]	validation-rmse:6.42154
# [545]	validation-rmse:6.42119
# [546]	validation-rmse:6.42091
# [547]	validation-rmse:6.42074
# [548]	validation-rmse:6.42074
# [549]	validation-rmse:6.42061
# [550]	validation-rmse:6.42057
# [551]	validation-rmse:6.42047
# [552]	validation-rmse:6.42039
# [553]	validation-rmse:6.42032
# [554]	validation-rmse:6.42023
# [555]	validation-rmse:6.42023
# [556]	validation-rmse:6.42018
# [557]	validation-rmse:6.42006
# [558]	validation-rmse:6.42001
# [559]	validation-rmse:6.41993
# [560]	validation-rmse:6.41985
# [561]	validation-rmse:6.41974
# [562]	validation-rmse:6.41946
# [563]	validation-rmse:6.41938
# [564]	validation-rmse:6.41936
# [565]	validation-rmse:6.41935
# [566]	validation-rmse:6.41933
# [567]	validation-rmse:6.41931
# [568]	validation-rmse:6.41914
# [569]	validation-rmse:6.41906
# [570]	validation-rmse:6.41904
# [571]	validation-rmse:6.41893
# [572]	validation-rmse:6.41890
# [573]	validation-rmse:6.41892
# [574]	validation-rmse:6.41883
# [575]	validation-rmse:6.41876
# [576]	validation-rmse:6.41858
# [577]	validation-rmse:6.41856
# [578]	validation-rmse:6.41850
# [579]	validation-rmse:6.41846
# [580]	validation-rmse:6.41831
# [581]	validation-rmse:6.41822
# [582]	validation-rmse:6.41822
# [583]	validation-rmse:6.41807
# [584]	validation-rmse:6.41802
# [585]	validation-rmse:6.41792
# [586]	validation-rmse:6.41776
# [587]	validation-rmse:6.41771
# [588]	validation-rmse:6.41770
# [589]	validation-rmse:6.41770
# [590]	validation-rmse:6.41771
# [591]	validation-rmse:6.41767
# [592]	validation-rmse:6.41760
# [593]	validation-rmse:6.41758
# [594]	validation-rmse:6.41746
# [595]	validation-rmse:6.41738
# [596]	validation-rmse:6.41732
# [597]	validation-rmse:6.41718
# [598]	validation-rmse:6.41712
# [599]	validation-rmse:6.41697
#  18%|█▊        | 9/50 [28:46<2:11:06, 191.87s/trial, best loss: 6.309972598289975]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[23], line 11
#       1 search_space = {
#       2     "max_depth": scope.int(hp.quniform("max_depth", 4, 100, 1)),
#       3     "learning_rate": hp.loguniform("learning_rate", -3, 0),
#    (...)
#       8     "seed": 42,
#       9 }
# ---> 11 best_result = fmin(
#      12     fn=objective,
#      13     space=search_space,
#      14     algo=tpe.suggest,
#      15     max_evals=50,
#      16     trials=Trials()
#      17 )
#
# File ~/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/hyperopt/fmin.py:540, in fmin(fn, space, algo, max_evals, timeout, loss_threshold, trials, rstate, allow_trials_fmin, pass_expr_memo_ctrl, catch_eval_exceptions, verbose, return_argmin, points_to_evaluate, max_queue_len, show_progressbar, early_stop_fn, trials_save_file)
#     537     fn = __objective_fmin_wrapper(fn)
#     539 if allow_trials_fmin and hasattr(trials, "fmin"):
# --> 540     return trials.fmin(
#     541         fn,
#     542         space,
#     543         algo=algo,
#     544         max_evals=max_evals,
#     545         timeout=timeout,
#     546         loss_threshold=loss_threshold,
#     547         max_queue_len=max_queue_len,
#     548         rstate=rstate,
#     549         pass_expr_memo_ctrl=pass_expr_memo_ctrl,
#     550         verbose=verbose,
#     551         catch_eval_exceptions=catch_eval_exceptions,
#     552         return_argmin=return_argmin,
#     553         show_progressbar=show_progressbar,
#     554         early_stop_fn=early_stop_fn,
#     555         trials_save_file=trials_save_file,
#     556     )
#     558 if trials is None:
#     559     if os.path.exists(trials_save_file):
#
# File ~/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/hyperopt/base.py:671, in Trials.fmin(self, fn, space, algo, max_evals, timeout, loss_threshold, max_queue_len, rstate, verbose, pass_expr_memo_ctrl, catch_eval_exceptions, return_argmin, show_progressbar, early_stop_fn, trials_save_file)
#     666 # -- Stop-gap implementation!
#     667 #    fmin should have been a Trials method in the first place
#     668 #    but for now it's still sitting in another file.
#     669 from .fmin import fmin
# --> 671 return fmin(
#     672     fn,
#     673     space,
#     674     algo=algo,
#     675     max_evals=max_evals,
#     676     timeout=timeout,
#     677     loss_threshold=loss_threshold,
#     678     trials=self,
#     679     rstate=rstate,
#     680     verbose=verbose,
#     681     max_queue_len=max_queue_len,
#     682     allow_trials_fmin=False,  # -- prevent recursion
#     683     pass_expr_memo_ctrl=pass_expr_memo_ctrl,
#     684     catch_eval_exceptions=catch_eval_exceptions,
#     685     return_argmin=return_argmin,
#     686     show_progressbar=show_progressbar,
#     687     early_stop_fn=early_stop_fn,
#     688     trials_save_file=trials_save_file,
#     689 )
#
# File ~/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/hyperopt/fmin.py:586, in fmin(fn, space, algo, max_evals, timeout, loss_threshold, trials, rstate, allow_trials_fmin, pass_expr_memo_ctrl, catch_eval_exceptions, verbose, return_argmin, points_to_evaluate, max_queue_len, show_progressbar, early_stop_fn, trials_save_file)
#     583 rval.catch_eval_exceptions = catch_eval_exceptions
#     585 # next line is where the fmin is actually executed
# --> 586 rval.exhaust()
#     588 if return_argmin:
#     589     if len(trials.trials) == 0:
#
# File ~/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/hyperopt/fmin.py:364, in FMinIter.exhaust(self)
#     362 def exhaust(self):
#     363     n_done = len(self.trials)
# --> 364     self.run(self.max_evals - n_done, block_until_done=self.asynchronous)
#     365     self.trials.refresh()
#     366     return self
#
# File ~/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/hyperopt/fmin.py:300, in FMinIter.run(self, N, block_until_done)
#     297     time.sleep(self.poll_interval_secs)
#     298 else:
#     299     # -- loop over trials and do the jobs directly
# --> 300     self.serial_evaluate()
#     302 self.trials.refresh()
#     303 if self.trials_save_file != "":
#
# File ~/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/hyperopt/fmin.py:178, in FMinIter.serial_evaluate(self, N)
#     176 ctrl = base.Ctrl(self.trials, current_trial=trial)
#     177 try:
# --> 178     result = self.domain.evaluate(spec, ctrl)
#     179 except Exception as e:
#     180     logger.error("job exception: %s" % str(e))
#
# File ~/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/hyperopt/base.py:892, in Domain.evaluate(self, config, ctrl, attach_attachments)
#     883 else:
#     884     # -- the "work" of evaluating `config` can be written
#     885     #    either into the pyll part (self.expr)
#     886     #    or the normal Python part (self.fn)
#     887     pyll_rval = pyll.rec_eval(
#     888         self.expr,
#     889         memo=memo,
#     890         print_node_on_error=self.rec_eval_print_node_on_error,
#     891     )
# --> 892     rval = self.fn(pyll_rval)
#     894 if isinstance(rval, (float, int, np.number)):
#     895     dict_rval = {"loss": float(rval), "status": STATUS_OK}
#
# Cell In[22], line 6, in objective(params)
#       4 mlflow.set_tag("model", "xgboost")
#       5 mlflow.log_params(params)
# ----> 6 booster = xgb.train(
#       7     params=params,
#       8     dtrain=train,
#       9     num_boost_round=1000,
#      10     evals=[(valid, "validation")],
#      11     early_stopping_rounds=50
#      12 )
#      13 y_pred = booster.predict(valid)
#      14 rmse = mean_squared_error(y_val, y_pred, squared=False)
#
# File ~/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/xgboost/core.py:726, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     724 for k, arg in zip(sig.parameters, args):
#     725     kwargs[k] = arg
# --> 726 return func(**kwargs)
#
# File ~/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/xgboost/training.py:182, in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks, custom_metric)
#     180         break
#     181     bst.update(dtrain, iteration=i, fobj=obj)
# --> 182     if cb_container.after_iteration(bst, i, dtrain, evals):
#     183         break
#     185 bst = cb_container.after_training(bst)
#
# File ~/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/xgboost/callback.py:258, in CallbackContainer.after_iteration(self, model, epoch, dtrain, evals)
#     256 for _, name in evals:
#     257     assert name.find("-") == -1, "Dataset name should not contain `-`"
# --> 258 score: str = model.eval_set(evals, epoch, self.metric, self._output_margin)
#     259 metric_score = _parse_eval_str(score)
#     260 self._update_history(metric_score, epoch)
#
# File ~/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/xgboost/core.py:2212, in Booster.eval_set(self, evals, iteration, feval, output_margin)
#    2209 evnames = c_array(ctypes.c_char_p, [c_str(d[1]) for d in evals])
#    2210 msg = ctypes.c_char_p()
#    2211 _check_call(
# -> 2212     _LIB.XGBoosterEvalOneIter(
#    2213         self.handle,
#    2214         ctypes.c_int(iteration),
#    2215         dmats,
#    2216         evnames,
#    2217         c_bst_ulong(len(evals)),
#    2218         ctypes.byref(msg),
#    2219     )
#    2220 )
#    2221 assert msg.value is not None
#    2222 res = msg.value.decode()  # pylint: disable=no-member
#
# KeyboardInterrupt:

# %%
params = {
    "learning_rate": 0.07779422828008767,
    "max_depth": 45,
    "min_child_weight": 1.2986450371090257,
    "objective": "reg:linear",
    "reg_alpha": 0.0632450975172789,
    "reg_lambda": 0.009296790888165441,
}

mlflow.xgboost.autolog()

booster = xgb.train(
            params=params,
            dtrain=train,
            num_boost_round=1000,
            evals=[(valid, "validation")],
            early_stopping_rounds=50
        )
# Out:
# 2024/07/17 12:05:58 WARNING mlflow.utils.autologging_utils: You are using an unsupported version of xgboost. If you encounter errors during autologging, try upgrading / downgrading xgboost to a supported version, or try upgrading MLflow.
# 2024/07/17 12:05:59 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'e2629be2a6fa499181df7e88f13a59b7', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
with mlflow.start_run():
    params = {
        "learning_rate": 0.07779422828008767,
        "max_depth": 45,
        "min_child_weight": 1.2986450371090257,
        "objective": "reg:linear",
        "reg_alpha": 0.0632450975172789,
        "reg_lambda": 0.009296790888165441,
        "seed": 42
    }

    mlflow.log_params(params)

    booster = xgb.train(
                params=params,
                dtrain=train,
                num_boost_round=1000,
                evals=[(valid, "validation")],
                early_stopping_rounds=50
            )
    
    y_preds = booster.predict(valid)
    rmse = mean_squared_error(y_val, y_preds, squared=False)
    mlflow.log_metric("rmse", rmse)

    with open("models/preprocessor.b", "wb") as f_out:
        pickle.dump(dv, f_out)

    mlflow.log_artifact("models/preprocessor.b", artifact_path="preprocessor")

    mlflow.xgboost.log_model(booster, artifact_path="models_mlflow")
# Out:
# /home/codespace/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [13:04:01] WARNING: /workspace/src/objective/regression_obj.cu:227: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)
# [0]	validation-rmse:11.58306
# [1]	validation-rmse:11.01649
# [2]	validation-rmse:10.50761
# [3]	validation-rmse:10.05159
# [4]	validation-rmse:9.64453
# [5]	validation-rmse:9.28100
# [6]	validation-rmse:8.95723
# [7]	validation-rmse:8.67070
# [8]	validation-rmse:8.41616
# [9]	validation-rmse:8.19136
# [10]	validation-rmse:7.99407
# [11]	validation-rmse:7.81902
# [12]	validation-rmse:7.66522
# [13]	validation-rmse:7.53066
# [14]	validation-rmse:7.41162
# [15]	validation-rmse:7.30582
# [16]	validation-rmse:7.21455
# [17]	validation-rmse:7.13239
# [18]	validation-rmse:7.06094
# [19]	validation-rmse:6.99793
# [20]	validation-rmse:6.94187
# [21]	validation-rmse:6.89282
# [22]	validation-rmse:6.84954
# [23]	validation-rmse:6.81077
# [24]	validation-rmse:6.77764
# [25]	validation-rmse:6.74742
# [26]	validation-rmse:6.72144
# [27]	validation-rmse:6.69833
# [28]	validation-rmse:6.67653
# [29]	validation-rmse:6.65721
# [30]	validation-rmse:6.63989
# [31]	validation-rmse:6.62368
# [32]	validation-rmse:6.60989
# [33]	validation-rmse:6.59743
# [34]	validation-rmse:6.58515
# [35]	validation-rmse:6.57422
# [36]	validation-rmse:6.56508
# [37]	validation-rmse:6.55664
# [38]	validation-rmse:6.54861
# [39]	validation-rmse:6.54137
# [40]	validation-rmse:6.53479
# [41]	validation-rmse:6.52860
# [42]	validation-rmse:6.52301
# [43]	validation-rmse:6.51802
# [44]	validation-rmse:6.51343
# [45]	validation-rmse:6.50913
# [46]	validation-rmse:6.50516
# [47]	validation-rmse:6.50195
# [48]	validation-rmse:6.49870
# [49]	validation-rmse:6.49550
# [50]	validation-rmse:6.49194
# [51]	validation-rmse:6.48899
# [52]	validation-rmse:6.48608
# [53]	validation-rmse:6.48389
# [54]	validation-rmse:6.48191
# [55]	validation-rmse:6.48037
# [56]	validation-rmse:6.47904
# [57]	validation-rmse:6.47776
# [58]	validation-rmse:6.47668
# [59]	validation-rmse:6.47535
# [60]	validation-rmse:6.47419
# [61]	validation-rmse:6.47296
# [62]	validation-rmse:6.47184
# [63]	validation-rmse:6.47112
# [64]	validation-rmse:6.46990
# [65]	validation-rmse:6.46921
# [66]	validation-rmse:6.46848
# [67]	validation-rmse:6.46775
# [68]	validation-rmse:6.46683
# [69]	validation-rmse:6.46659
# [70]	validation-rmse:6.46550
# [71]	validation-rmse:6.46499
# [72]	validation-rmse:6.46437
# [73]	validation-rmse:6.46352
# [74]	validation-rmse:6.46277
# [75]	validation-rmse:6.46171
# [76]	validation-rmse:6.46067
# [77]	validation-rmse:6.45991
# [78]	validation-rmse:6.45915
# [79]	validation-rmse:6.45772
# [80]	validation-rmse:6.45729
# [81]	validation-rmse:6.45660
# [82]	validation-rmse:6.45604
# [83]	validation-rmse:6.45543
# [84]	validation-rmse:6.45415
# [85]	validation-rmse:6.45359
# [86]	validation-rmse:6.45303
# [87]	validation-rmse:6.45222
# [88]	validation-rmse:6.45180
# [89]	validation-rmse:6.45126
# [90]	validation-rmse:6.45061
# [91]	validation-rmse:6.44982
# [92]	validation-rmse:6.44902
# [93]	validation-rmse:6.44806
# [94]	validation-rmse:6.44736
# [95]	validation-rmse:6.44680
# [96]	validation-rmse:6.44592
# [97]	validation-rmse:6.44551
# [98]	validation-rmse:6.44488
# [99]	validation-rmse:6.44435
# [100]	validation-rmse:6.44342
# [101]	validation-rmse:6.44280
# [102]	validation-rmse:6.44241
# [103]	validation-rmse:6.44168
# [104]	validation-rmse:6.44076
# [105]	validation-rmse:6.44004
# [106]	validation-rmse:6.43952
# [107]	validation-rmse:6.43870
# [108]	validation-rmse:6.43830
# [109]	validation-rmse:6.43814
# [110]	validation-rmse:6.43765
# [111]	validation-rmse:6.43721
# [112]	validation-rmse:6.43656
# [113]	validation-rmse:6.43574
# [114]	validation-rmse:6.43521
# [115]	validation-rmse:6.43440
# [116]	validation-rmse:6.43387
# [117]	validation-rmse:6.43324
# [118]	validation-rmse:6.43279
# [119]	validation-rmse:6.43236
# [120]	validation-rmse:6.43188
# [121]	validation-rmse:6.43127
# [122]	validation-rmse:6.43080
# [123]	validation-rmse:6.43010
# [124]	validation-rmse:6.42968
# [125]	validation-rmse:6.42923
# [126]	validation-rmse:6.42875
# [127]	validation-rmse:6.42808
# [128]	validation-rmse:6.42779
# [129]	validation-rmse:6.42671
# [130]	validation-rmse:6.42646
# [131]	validation-rmse:6.42597
# [132]	validation-rmse:6.42532
# [133]	validation-rmse:6.42492
# [134]	validation-rmse:6.42480
# [135]	validation-rmse:6.42449
# [136]	validation-rmse:6.42413
# [137]	validation-rmse:6.42339
# [138]	validation-rmse:6.42291
# [139]	validation-rmse:6.42232
# [140]	validation-rmse:6.42174
# [141]	validation-rmse:6.42121
# [142]	validation-rmse:6.42068
# [143]	validation-rmse:6.42016
# [144]	validation-rmse:6.41970
# [145]	validation-rmse:6.41916
# [146]	validation-rmse:6.41877
# [147]	validation-rmse:6.41846
# [148]	validation-rmse:6.41809
# [149]	validation-rmse:6.41757
# [150]	validation-rmse:6.41732
# [151]	validation-rmse:6.41687
# [152]	validation-rmse:6.41645
# [153]	validation-rmse:6.41599
# [154]	validation-rmse:6.41570
# [155]	validation-rmse:6.41535
# [156]	validation-rmse:6.41505
# [157]	validation-rmse:6.41440
# [158]	validation-rmse:6.41383
# [159]	validation-rmse:6.41326
# [160]	validation-rmse:6.41278
# [161]	validation-rmse:6.41227
# [162]	validation-rmse:6.41198
# [163]	validation-rmse:6.41165
# [164]	validation-rmse:6.41129
# [165]	validation-rmse:6.41096
# [166]	validation-rmse:6.41076
# [167]	validation-rmse:6.41048
# [168]	validation-rmse:6.41006
# [169]	validation-rmse:6.40958
# [170]	validation-rmse:6.40909
# [171]	validation-rmse:6.40853
# [172]	validation-rmse:6.40816
# [173]	validation-rmse:6.40772
# [174]	validation-rmse:6.40725
# [175]	validation-rmse:6.40684
# [176]	validation-rmse:6.40645
# [177]	validation-rmse:6.40606
# [178]	validation-rmse:6.40555
# [179]	validation-rmse:6.40521
# [180]	validation-rmse:6.40502
# [181]	validation-rmse:6.40463
# [182]	validation-rmse:6.40427
# [183]	validation-rmse:6.40407
# [184]	validation-rmse:6.40368
# [185]	validation-rmse:6.40341
# [186]	validation-rmse:6.40297
# [187]	validation-rmse:6.40272
# [188]	validation-rmse:6.40238
# [189]	validation-rmse:6.40206
# [190]	validation-rmse:6.40178
# [191]	validation-rmse:6.40146
# [192]	validation-rmse:6.40100
# [193]	validation-rmse:6.40049
# [194]	validation-rmse:6.39984
# [195]	validation-rmse:6.39960
# [196]	validation-rmse:6.39943
# [197]	validation-rmse:6.39910
# [198]	validation-rmse:6.39864
# [199]	validation-rmse:6.39849
# [200]	validation-rmse:6.39825
# [201]	validation-rmse:6.39798
# [202]	validation-rmse:6.39767
# [203]	validation-rmse:6.39751
# [204]	validation-rmse:6.39729
# [205]	validation-rmse:6.39673
# [206]	validation-rmse:6.39632
# [207]	validation-rmse:6.39598
# [208]	validation-rmse:6.39560
# [209]	validation-rmse:6.39515
# [210]	validation-rmse:6.39477
# [211]	validation-rmse:6.39446
# [212]	validation-rmse:6.39416
# [213]	validation-rmse:6.39374
# [214]	validation-rmse:6.39338
# [215]	validation-rmse:6.39304
# [216]	validation-rmse:6.39270
# [217]	validation-rmse:6.39236
# [218]	validation-rmse:6.39209
# [219]	validation-rmse:6.39189
# [220]	validation-rmse:6.39171
# [221]	validation-rmse:6.39139
# [222]	validation-rmse:6.39109
# [223]	validation-rmse:6.39085
# [224]	validation-rmse:6.39061
# [225]	validation-rmse:6.39032
# [226]	validation-rmse:6.39019
# [227]	validation-rmse:6.38971
# [228]	validation-rmse:6.38949
# [229]	validation-rmse:6.38933
# [230]	validation-rmse:6.38917
# [231]	validation-rmse:6.38874
# [232]	validation-rmse:6.38860
# [233]	validation-rmse:6.38809
# [234]	validation-rmse:6.38785
# [235]	validation-rmse:6.38755
# [236]	validation-rmse:6.38729
# [237]	validation-rmse:6.38708
# [238]	validation-rmse:6.38659
# [239]	validation-rmse:6.38634
# [240]	validation-rmse:6.38621
# [241]	validation-rmse:6.38589
# [242]	validation-rmse:6.38566
# [243]	validation-rmse:6.38539
# [244]	validation-rmse:6.38515
# [245]	validation-rmse:6.38498
# [246]	validation-rmse:6.38477
# [247]	validation-rmse:6.38478
# [248]	validation-rmse:6.38452
# [249]	validation-rmse:6.38432
# [250]	validation-rmse:6.38396
# [251]	validation-rmse:6.38336
# [252]	validation-rmse:6.38306
# [253]	validation-rmse:6.38278
# [254]	validation-rmse:6.38264
# [255]	validation-rmse:6.38249
# [256]	validation-rmse:6.38209
# [257]	validation-rmse:6.38181
# [258]	validation-rmse:6.38162
# [259]	validation-rmse:6.38133
# [260]	validation-rmse:6.38115
# [261]	validation-rmse:6.38088
# [262]	validation-rmse:6.38051
# [263]	validation-rmse:6.38021
# [264]	validation-rmse:6.37997
# [265]	validation-rmse:6.37979
# [266]	validation-rmse:6.37970
# [267]	validation-rmse:6.37951
# [268]	validation-rmse:6.37912
# [269]	validation-rmse:6.37893
# [270]	validation-rmse:6.37882
# [271]	validation-rmse:6.37857
# [272]	validation-rmse:6.37840
# [273]	validation-rmse:6.37801
# [274]	validation-rmse:6.37791
# [275]	validation-rmse:6.37750
# [276]	validation-rmse:6.37732
# [277]	validation-rmse:6.37724
# [278]	validation-rmse:6.37700
# [279]	validation-rmse:6.37681
# [280]	validation-rmse:6.37670
# [281]	validation-rmse:6.37624
# [282]	validation-rmse:6.37608
# [283]	validation-rmse:6.37589
# [284]	validation-rmse:6.37568
# [285]	validation-rmse:6.37543
# [286]	validation-rmse:6.37509
# [287]	validation-rmse:6.37488
# [288]	validation-rmse:6.37462
# [289]	validation-rmse:6.37446
# [290]	validation-rmse:6.37425
# [291]	validation-rmse:6.37409
# [292]	validation-rmse:6.37374
# [293]	validation-rmse:6.37363
# [294]	validation-rmse:6.37343
# [295]	validation-rmse:6.37322
# [296]	validation-rmse:6.37299
# [297]	validation-rmse:6.37291
# [298]	validation-rmse:6.37268
# [299]	validation-rmse:6.37270
# [300]	validation-rmse:6.37242
# [301]	validation-rmse:6.37207
# [302]	validation-rmse:6.37187
# [303]	validation-rmse:6.37145
# [304]	validation-rmse:6.37125
# [305]	validation-rmse:6.37100
# [306]	validation-rmse:6.37091
# [307]	validation-rmse:6.37064
# [308]	validation-rmse:6.37048
# [309]	validation-rmse:6.37020
# [310]	validation-rmse:6.37001
# [311]	validation-rmse:6.36975
# [312]	validation-rmse:6.36943
# [313]	validation-rmse:6.36925
# [314]	validation-rmse:6.36892
# [315]	validation-rmse:6.36884
# [316]	validation-rmse:6.36873
# [317]	validation-rmse:6.36846
# [318]	validation-rmse:6.36815
# [319]	validation-rmse:6.36776
# [320]	validation-rmse:6.36774
# [321]	validation-rmse:6.36746
# [322]	validation-rmse:6.36729
# [323]	validation-rmse:6.36711
# [324]	validation-rmse:6.36693
# [325]	validation-rmse:6.36678
# [326]	validation-rmse:6.36668
# [327]	validation-rmse:6.36666
# [328]	validation-rmse:6.36647
# [329]	validation-rmse:6.36639
# [330]	validation-rmse:6.36626
# [331]	validation-rmse:6.36592
# [332]	validation-rmse:6.36584
# [333]	validation-rmse:6.36570
# [334]	validation-rmse:6.36530
# [335]	validation-rmse:6.36521
# [336]	validation-rmse:6.36511
# [337]	validation-rmse:6.36498
# [338]	validation-rmse:6.36480
# [339]	validation-rmse:6.36470
# [340]	validation-rmse:6.36422
# [341]	validation-rmse:6.36404
# [342]	validation-rmse:6.36374
# [343]	validation-rmse:6.36377
# [344]	validation-rmse:6.36355
# [345]	validation-rmse:6.36341
# [346]	validation-rmse:6.36326
# [347]	validation-rmse:6.36296
# [348]	validation-rmse:6.36267
# [349]	validation-rmse:6.36262
# [350]	validation-rmse:6.36250
# [351]	validation-rmse:6.36225
# [352]	validation-rmse:6.36190
# [353]	validation-rmse:6.36181
# [354]	validation-rmse:6.36175
# [355]	validation-rmse:6.36153
# [356]	validation-rmse:6.36137
# [357]	validation-rmse:6.36122
# [358]	validation-rmse:6.36105
# [359]	validation-rmse:6.36087
# [360]	validation-rmse:6.36071
# [361]	validation-rmse:6.36072
# [362]	validation-rmse:6.36054
# [363]	validation-rmse:6.36054
# [364]	validation-rmse:6.36042
# [365]	validation-rmse:6.36017
# [366]	validation-rmse:6.36003
# [367]	validation-rmse:6.35961
# [368]	validation-rmse:6.35955
# [369]	validation-rmse:6.35941
# [370]	validation-rmse:6.35925
# [371]	validation-rmse:6.35920
# [372]	validation-rmse:6.35899
# [373]	validation-rmse:6.35874
# [374]	validation-rmse:6.35854
# [375]	validation-rmse:6.35854
# [376]	validation-rmse:6.35832
# [377]	validation-rmse:6.35814
# [378]	validation-rmse:6.35801
# [379]	validation-rmse:6.35783
# [380]	validation-rmse:6.35760
# [381]	validation-rmse:6.35725
# [382]	validation-rmse:6.35709
# [383]	validation-rmse:6.35694
# [384]	validation-rmse:6.35676
# [385]	validation-rmse:6.35656
# [386]	validation-rmse:6.35658
# [387]	validation-rmse:6.35644
# [388]	validation-rmse:6.35631
# [389]	validation-rmse:6.35622
# [390]	validation-rmse:6.35624
# [391]	validation-rmse:6.35624
# [392]	validation-rmse:6.35615
# [393]	validation-rmse:6.35622
# [394]	validation-rmse:6.35603
# [395]	validation-rmse:6.35581
# [396]	validation-rmse:6.35566
# [397]	validation-rmse:6.35560
# [398]	validation-rmse:6.35536
# [399]	validation-rmse:6.35525
# [400]	validation-rmse:6.35503
# [401]	validation-rmse:6.35498
# [402]	validation-rmse:6.35468
# [403]	validation-rmse:6.35436
# [404]	validation-rmse:6.35430
# [405]	validation-rmse:6.35416
# [406]	validation-rmse:6.35405
# [407]	validation-rmse:6.35382
# [408]	validation-rmse:6.35368
# [409]	validation-rmse:6.35348
# [410]	validation-rmse:6.35333
# [411]	validation-rmse:6.35307
# [412]	validation-rmse:6.35300
# [413]	validation-rmse:6.35295
# [414]	validation-rmse:6.35280
# [415]	validation-rmse:6.35243
# [416]	validation-rmse:6.35228
# [417]	validation-rmse:6.35214
# [418]	validation-rmse:6.35195
# [419]	validation-rmse:6.35189
# [420]	validation-rmse:6.35139
# [421]	validation-rmse:6.35124
# [422]	validation-rmse:6.35112
# [423]	validation-rmse:6.35098
# [424]	validation-rmse:6.35084
# [425]	validation-rmse:6.35075
# [426]	validation-rmse:6.35065
# [427]	validation-rmse:6.35024
# [428]	validation-rmse:6.35016
# [429]	validation-rmse:6.35005
# [430]	validation-rmse:6.35013
# [431]	validation-rmse:6.35007
# [432]	validation-rmse:6.35001
# [433]	validation-rmse:6.34986
# [434]	validation-rmse:6.34994
# [435]	validation-rmse:6.34987
# [436]	validation-rmse:6.34967
# [437]	validation-rmse:6.34930
# [438]	validation-rmse:6.34919
# [439]	validation-rmse:6.34875
# [440]	validation-rmse:6.34858
# [441]	validation-rmse:6.34841
# [442]	validation-rmse:6.34835
# [443]	validation-rmse:6.34829
# [444]	validation-rmse:6.34816
# [445]	validation-rmse:6.34807
# [446]	validation-rmse:6.34790
# [447]	validation-rmse:6.34770
# [448]	validation-rmse:6.34727
# [449]	validation-rmse:6.34723
# [450]	validation-rmse:6.34704
# [451]	validation-rmse:6.34696
# [452]	validation-rmse:6.34685
# [453]	validation-rmse:6.34674
# [454]	validation-rmse:6.34659
# [455]	validation-rmse:6.34643
# [456]	validation-rmse:6.34643
# [457]	validation-rmse:6.34633
# [458]	validation-rmse:6.34635
# [459]	validation-rmse:6.34632
# [460]	validation-rmse:6.34606
# [461]	validation-rmse:6.34615
# [462]	validation-rmse:6.34614
# [463]	validation-rmse:6.34610
# [464]	validation-rmse:6.34591
# [465]	validation-rmse:6.34585
# [466]	validation-rmse:6.34589
# [467]	validation-rmse:6.34576
# [468]	validation-rmse:6.34566
# [469]	validation-rmse:6.34568
# [470]	validation-rmse:6.34554
# [471]	validation-rmse:6.34535
# [472]	validation-rmse:6.34519
# [473]	validation-rmse:6.34496
# [474]	validation-rmse:6.34490
# [475]	validation-rmse:6.34466
# [476]	validation-rmse:6.34457
# [477]	validation-rmse:6.34438
# [478]	validation-rmse:6.34426
# [479]	validation-rmse:6.34419
# [480]	validation-rmse:6.34396
# [481]	validation-rmse:6.34381
# [482]	validation-rmse:6.34351
# [483]	validation-rmse:6.34332
# [484]	validation-rmse:6.34309
# [485]	validation-rmse:6.34292
# [486]	validation-rmse:6.34274
# [487]	validation-rmse:6.34265
# [488]	validation-rmse:6.34258
# [489]	validation-rmse:6.34249
# [490]	validation-rmse:6.34239
# [491]	validation-rmse:6.34226
# [492]	validation-rmse:6.34212
# [493]	validation-rmse:6.34199
# [494]	validation-rmse:6.34185
# [495]	validation-rmse:6.34160
# [496]	validation-rmse:6.34148
# [497]	validation-rmse:6.34130
# [498]	validation-rmse:6.34113
# [499]	validation-rmse:6.34105
# [500]	validation-rmse:6.34083
# [501]	validation-rmse:6.34074
# [502]	validation-rmse:6.34070
# [503]	validation-rmse:6.34063
# [504]	validation-rmse:6.34035
# [505]	validation-rmse:6.34018
# [506]	validation-rmse:6.34027
# [507]	validation-rmse:6.34020
# [508]	validation-rmse:6.34012
# [509]	validation-rmse:6.34000
# [510]	validation-rmse:6.33988
# [511]	validation-rmse:6.33988
# [512]	validation-rmse:6.33975
# [513]	validation-rmse:6.33967
# [514]	validation-rmse:6.33948
# [515]	validation-rmse:6.33936
# [516]	validation-rmse:6.33902
# [517]	validation-rmse:6.33887
# [518]	validation-rmse:6.33877
# [519]	validation-rmse:6.33856
# [520]	validation-rmse:6.33841
# [521]	validation-rmse:6.33837
# [522]	validation-rmse:6.33823
# [523]	validation-rmse:6.33814
# [524]	validation-rmse:6.33792
# [525]	validation-rmse:6.33792
# [526]	validation-rmse:6.33785
# [527]	validation-rmse:6.33786
# [528]	validation-rmse:6.33780
# [529]	validation-rmse:6.33775
# [530]	validation-rmse:6.33776
# [531]	validation-rmse:6.33759
# [532]	validation-rmse:6.33754
# [533]	validation-rmse:6.33754
# [534]	validation-rmse:6.33751
# [535]	validation-rmse:6.33746
# [536]	validation-rmse:6.33728
# [537]	validation-rmse:6.33725
# [538]	validation-rmse:6.33705
# [539]	validation-rmse:6.33700
# [540]	validation-rmse:6.33699
# [541]	validation-rmse:6.33686
# [542]	validation-rmse:6.33678
# [543]	validation-rmse:6.33669
# [544]	validation-rmse:6.33657
# [545]	validation-rmse:6.33651
# [546]	validation-rmse:6.33646
# [547]	validation-rmse:6.33648
# [548]	validation-rmse:6.33655
# [549]	validation-rmse:6.33642
# [550]	validation-rmse:6.33624
# [551]	validation-rmse:6.33622
# [552]	validation-rmse:6.33604
# [553]	validation-rmse:6.33600
# [554]	validation-rmse:6.33591
# [555]	validation-rmse:6.33583
# [556]	validation-rmse:6.33574
# [557]	validation-rmse:6.33559
# [558]	validation-rmse:6.33544
# [559]	validation-rmse:6.33529
# [560]	validation-rmse:6.33509
# [561]	validation-rmse:6.33506
# [562]	validation-rmse:6.33492
# [563]	validation-rmse:6.33479
# [564]	validation-rmse:6.33468
# [565]	validation-rmse:6.33457
# [566]	validation-rmse:6.33440
# [567]	validation-rmse:6.33433
# [568]	validation-rmse:6.33423
# [569]	validation-rmse:6.33424
# [570]	validation-rmse:6.33422
# [571]	validation-rmse:6.33415
# [572]	validation-rmse:6.33403
# [573]	validation-rmse:6.33394
# [574]	validation-rmse:6.33390
# [575]	validation-rmse:6.33366
# [576]	validation-rmse:6.33356
# [577]	validation-rmse:6.33340
# [578]	validation-rmse:6.33329
# [579]	validation-rmse:6.33327
# [580]	validation-rmse:6.33323
# [581]	validation-rmse:6.33322
# [582]	validation-rmse:6.33317
# [583]	validation-rmse:6.33297
# [584]	validation-rmse:6.33289
# [585]	validation-rmse:6.33283
# [586]	validation-rmse:6.33258
# [587]	validation-rmse:6.33240
# [588]	validation-rmse:6.33246
# [589]	validation-rmse:6.33258
# [590]	validation-rmse:6.33255
# [591]	validation-rmse:6.33230
# [592]	validation-rmse:6.33237
# [593]	validation-rmse:6.33223
# [594]	validation-rmse:6.33210
# [595]	validation-rmse:6.33205
# [596]	validation-rmse:6.33193
# [597]	validation-rmse:6.33179
# [598]	validation-rmse:6.33180
# [599]	validation-rmse:6.33181
# [600]	validation-rmse:6.33175
# [601]	validation-rmse:6.33167
# [602]	validation-rmse:6.33162
# [603]	validation-rmse:6.33130
# [604]	validation-rmse:6.33123
# [605]	validation-rmse:6.33121
# [606]	validation-rmse:6.33114
# [607]	validation-rmse:6.33110
# [608]	validation-rmse:6.33091
# [609]	validation-rmse:6.33080
# [610]	validation-rmse:6.33064
# [611]	validation-rmse:6.33068
# [612]	validation-rmse:6.33075
# [613]	validation-rmse:6.33067
# [614]	validation-rmse:6.33073
# [615]	validation-rmse:6.33073
# [616]	validation-rmse:6.33059
# [617]	validation-rmse:6.33062
# [618]	validation-rmse:6.33055
# [619]	validation-rmse:6.33047
# [620]	validation-rmse:6.33029
# [621]	validation-rmse:6.33026
# [622]	validation-rmse:6.32994
# [623]	validation-rmse:6.32995
# [624]	validation-rmse:6.32980
# [625]	validation-rmse:6.32954
# [626]	validation-rmse:6.32937
# [627]	validation-rmse:6.32938
# [628]	validation-rmse:6.32903
# [629]	validation-rmse:6.32909
# [630]	validation-rmse:6.32896
# [631]	validation-rmse:6.32865
# [632]	validation-rmse:6.32861
# [633]	validation-rmse:6.32851
# [634]	validation-rmse:6.32826
# [635]	validation-rmse:6.32822
# [636]	validation-rmse:6.32814
# [637]	validation-rmse:6.32809
# [638]	validation-rmse:6.32816
# [639]	validation-rmse:6.32811
# [640]	validation-rmse:6.32803
# [641]	validation-rmse:6.32794
# [642]	validation-rmse:6.32779
# [643]	validation-rmse:6.32771
# [644]	validation-rmse:6.32762
# [645]	validation-rmse:6.32748
# [646]	validation-rmse:6.32749
# [647]	validation-rmse:6.32740
# [648]	validation-rmse:6.32731
# [649]	validation-rmse:6.32726
# [650]	validation-rmse:6.32725
# [651]	validation-rmse:6.32708
# [652]	validation-rmse:6.32698
# [653]	validation-rmse:6.32691
# [654]	validation-rmse:6.32688
# [655]	validation-rmse:6.32680
# [656]	validation-rmse:6.32652
# [657]	validation-rmse:6.32662
# [658]	validation-rmse:6.32642
# [659]	validation-rmse:6.32642
# [660]	validation-rmse:6.32630
# [661]	validation-rmse:6.32623
# [662]	validation-rmse:6.32619
# [663]	validation-rmse:6.32610
# [664]	validation-rmse:6.32612
# [665]	validation-rmse:6.32557
# [666]	validation-rmse:6.32540
# [667]	validation-rmse:6.32532
# [668]	validation-rmse:6.32522
# [669]	validation-rmse:6.32500
# [670]	validation-rmse:6.32501
# [671]	validation-rmse:6.32498
# [672]	validation-rmse:6.32488
# [673]	validation-rmse:6.32492
# [674]	validation-rmse:6.32479
# [675]	validation-rmse:6.32476
# [676]	validation-rmse:6.32473
# [677]	validation-rmse:6.32472
# [678]	validation-rmse:6.32465
# [679]	validation-rmse:6.32442
# [680]	validation-rmse:6.32437
# [681]	validation-rmse:6.32429
# [682]	validation-rmse:6.32438
# [683]	validation-rmse:6.32442
# [684]	validation-rmse:6.32423
# [685]	validation-rmse:6.32419
# [686]	validation-rmse:6.32407
# [687]	validation-rmse:6.32408
# [688]	validation-rmse:6.32401
# [689]	validation-rmse:6.32396
# [690]	validation-rmse:6.32381
# [691]	validation-rmse:6.32359
# [692]	validation-rmse:6.32342
# [693]	validation-rmse:6.32326
# [694]	validation-rmse:6.32331
# [695]	validation-rmse:6.32334
# [696]	validation-rmse:6.32312
# [697]	validation-rmse:6.32299
# [698]	validation-rmse:6.32287
# [699]	validation-rmse:6.32278
# [700]	validation-rmse:6.32281
# [701]	validation-rmse:6.32245
# [702]	validation-rmse:6.32238
# [703]	validation-rmse:6.32230
# [704]	validation-rmse:6.32248
# [705]	validation-rmse:6.32250
# [706]	validation-rmse:6.32253
# [707]	validation-rmse:6.32245
# [708]	validation-rmse:6.32250
# [709]	validation-rmse:6.32247
# [710]	validation-rmse:6.32222
# [711]	validation-rmse:6.32231
# [712]	validation-rmse:6.32215
# [713]	validation-rmse:6.32189
# [714]	validation-rmse:6.32201
# [715]	validation-rmse:6.32198
# [716]	validation-rmse:6.32191
# [717]	validation-rmse:6.32192
# [718]	validation-rmse:6.32181
# [719]	validation-rmse:6.32167
# [720]	validation-rmse:6.32157
# [721]	validation-rmse:6.32153
# [722]	validation-rmse:6.32148
# [723]	validation-rmse:6.32133
# [724]	validation-rmse:6.32133
# [725]	validation-rmse:6.32125
# [726]	validation-rmse:6.32125
# [727]	validation-rmse:6.32116
# [728]	validation-rmse:6.32114
# [729]	validation-rmse:6.32112
# [730]	validation-rmse:6.32093
# [731]	validation-rmse:6.32072
# [732]	validation-rmse:6.32073
# [733]	validation-rmse:6.32042
# [734]	validation-rmse:6.32018
# [735]	validation-rmse:6.32019
# [736]	validation-rmse:6.32006
# [737]	validation-rmse:6.32002
# [738]	validation-rmse:6.32004
# [739]	validation-rmse:6.32010
# [740]	validation-rmse:6.32008
# [741]	validation-rmse:6.32014
# [742]	validation-rmse:6.32000
# [743]	validation-rmse:6.31997
# [744]	validation-rmse:6.31995
# [745]	validation-rmse:6.31986
# [746]	validation-rmse:6.31977
# [747]	validation-rmse:6.31969
# [748]	validation-rmse:6.31963
# [749]	validation-rmse:6.31958
# [750]	validation-rmse:6.31962
# [751]	validation-rmse:6.31953
# [752]	validation-rmse:6.31943
# [753]	validation-rmse:6.31941
# [754]	validation-rmse:6.31938
# [755]	validation-rmse:6.31928
# [756]	validation-rmse:6.31931
# [757]	validation-rmse:6.31930
# [758]	validation-rmse:6.31923
# [759]	validation-rmse:6.31922
# [760]	validation-rmse:6.31909
# [761]	validation-rmse:6.31902
# [762]	validation-rmse:6.31898
# [763]	validation-rmse:6.31899
# [764]	validation-rmse:6.31886
# [765]	validation-rmse:6.31862
# [766]	validation-rmse:6.31857
# [767]	validation-rmse:6.31859
# [768]	validation-rmse:6.31874
# [769]	validation-rmse:6.31860
# [770]	validation-rmse:6.31845
# [771]	validation-rmse:6.31827
# [772]	validation-rmse:6.31814
# [773]	validation-rmse:6.31818
# [774]	validation-rmse:6.31791
# [775]	validation-rmse:6.31777
# [776]	validation-rmse:6.31774
# [777]	validation-rmse:6.31771
# [778]	validation-rmse:6.31760
# [779]	validation-rmse:6.31747
# [780]	validation-rmse:6.31735
# [781]	validation-rmse:6.31738
# [782]	validation-rmse:6.31743
# [783]	validation-rmse:6.31736
# [784]	validation-rmse:6.31752
# [785]	validation-rmse:6.31750
# [786]	validation-rmse:6.31749
# [787]	validation-rmse:6.31745
# [788]	validation-rmse:6.31746
# [789]	validation-rmse:6.31746
# [790]	validation-rmse:6.31749
# [791]	validation-rmse:6.31751
# [792]	validation-rmse:6.31754
# [793]	validation-rmse:6.31750
# [794]	validation-rmse:6.31742
# [795]	validation-rmse:6.31725
# [796]	validation-rmse:6.31666
# [797]	validation-rmse:6.31659
# [798]	validation-rmse:6.31653
# [799]	validation-rmse:6.31648
# [800]	validation-rmse:6.31648
# [801]	validation-rmse:6.31644
# [802]	validation-rmse:6.31641
# [803]	validation-rmse:6.31638
# [804]	validation-rmse:6.31643
# [805]	validation-rmse:6.31636
# [806]	validation-rmse:6.31635
# [807]	validation-rmse:6.31630
# [808]	validation-rmse:6.31615
# [809]	validation-rmse:6.31615
# [810]	validation-rmse:6.31618
# [811]	validation-rmse:6.31601
# [812]	validation-rmse:6.31617
# [813]	validation-rmse:6.31615
# [814]	validation-rmse:6.31611
# [815]	validation-rmse:6.31607
# [816]	validation-rmse:6.31599
# [817]	validation-rmse:6.31607
# [818]	validation-rmse:6.31577
# [819]	validation-rmse:6.31582
# [820]	validation-rmse:6.31569
# [821]	validation-rmse:6.31563
# [822]	validation-rmse:6.31547
# [823]	validation-rmse:6.31536
# [824]	validation-rmse:6.31524
# [825]	validation-rmse:6.31524
# [826]	validation-rmse:6.31523
# [827]	validation-rmse:6.31519
# [828]	validation-rmse:6.31519
# [829]	validation-rmse:6.31517
# [830]	validation-rmse:6.31506
# [831]	validation-rmse:6.31514
# [832]	validation-rmse:6.31512
# [833]	validation-rmse:6.31510
# [834]	validation-rmse:6.31492
# [835]	validation-rmse:6.31486
# [836]	validation-rmse:6.31483
# [837]	validation-rmse:6.31485
# [838]	validation-rmse:6.31479
# [839]	validation-rmse:6.31484
# [840]	validation-rmse:6.31477
# [841]	validation-rmse:6.31470
# [842]	validation-rmse:6.31471
# [843]	validation-rmse:6.31473
# [844]	validation-rmse:6.31467
# [845]	validation-rmse:6.31467
# [846]	validation-rmse:6.31467
# [847]	validation-rmse:6.31464
# [848]	validation-rmse:6.31444
# [849]	validation-rmse:6.31448
# [850]	validation-rmse:6.31434
# [851]	validation-rmse:6.31423
# [852]	validation-rmse:6.31407
# [853]	validation-rmse:6.31403
# [854]	validation-rmse:6.31397
# [855]	validation-rmse:6.31387
# [856]	validation-rmse:6.31394
# [857]	validation-rmse:6.31388
# [858]	validation-rmse:6.31395
# [859]	validation-rmse:6.31405
# [860]	validation-rmse:6.31405
# [861]	validation-rmse:6.31403
# [862]	validation-rmse:6.31392
# [863]	validation-rmse:6.31390
# [864]	validation-rmse:6.31387
# [865]	validation-rmse:6.31381
# [866]	validation-rmse:6.31382
# [867]	validation-rmse:6.31391
# [868]	validation-rmse:6.31385
# [869]	validation-rmse:6.31390
# [870]	validation-rmse:6.31381
# [871]	validation-rmse:6.31357
# [872]	validation-rmse:6.31362
# [873]	validation-rmse:6.31356
# [874]	validation-rmse:6.31360
# [875]	validation-rmse:6.31347
# [876]	validation-rmse:6.31345
# [877]	validation-rmse:6.31315
# [878]	validation-rmse:6.31299
# [879]	validation-rmse:6.31293
# [880]	validation-rmse:6.31292
# [881]	validation-rmse:6.31293
# [882]	validation-rmse:6.31285
# [883]	validation-rmse:6.31296
# [884]	validation-rmse:6.31293
# [885]	validation-rmse:6.31268
# [886]	validation-rmse:6.31273
# [887]	validation-rmse:6.31269
# [888]	validation-rmse:6.31279
# [889]	validation-rmse:6.31264
# [890]	validation-rmse:6.31256
# [891]	validation-rmse:6.31244
# [892]	validation-rmse:6.31243
# [893]	validation-rmse:6.31253
# [894]	validation-rmse:6.31251
# [895]	validation-rmse:6.31244
# [896]	validation-rmse:6.31246
# [897]	validation-rmse:6.31230
# [898]	validation-rmse:6.31235
# [899]	validation-rmse:6.31232
# [900]	validation-rmse:6.31224
# [901]	validation-rmse:6.31222
# [902]	validation-rmse:6.31215
# [903]	validation-rmse:6.31212
# [904]	validation-rmse:6.31205
# [905]	validation-rmse:6.31210
# [906]	validation-rmse:6.31221
# [907]	validation-rmse:6.31205
# [908]	validation-rmse:6.31199
# [909]	validation-rmse:6.31195
# [910]	validation-rmse:6.31196
# [911]	validation-rmse:6.31190
# [912]	validation-rmse:6.31184
# [913]	validation-rmse:6.31184
# [914]	validation-rmse:6.31187
# [915]	validation-rmse:6.31181
# [916]	validation-rmse:6.31179
# [917]	validation-rmse:6.31181
# [918]	validation-rmse:6.31168
# [919]	validation-rmse:6.31173
# [920]	validation-rmse:6.31170
# [921]	validation-rmse:6.31166
# [922]	validation-rmse:6.31158
# [923]	validation-rmse:6.31157
# [924]	validation-rmse:6.31161
# [925]	validation-rmse:6.31152
# [926]	validation-rmse:6.31143
# [927]	validation-rmse:6.31138
# [928]	validation-rmse:6.31143
# [929]	validation-rmse:6.31136
# [930]	validation-rmse:6.31138
# [931]	validation-rmse:6.31134
# [932]	validation-rmse:6.31122
# [933]	validation-rmse:6.31113
# [934]	validation-rmse:6.31102
# [935]	validation-rmse:6.31100
# [936]	validation-rmse:6.31101
# [937]	validation-rmse:6.31093
# [938]	validation-rmse:6.31090
# [939]	validation-rmse:6.31087
# [940]	validation-rmse:6.31089
# [941]	validation-rmse:6.31087
# [942]	validation-rmse:6.31086
# [943]	validation-rmse:6.31079
# [944]	validation-rmse:6.31072
# [945]	validation-rmse:6.31060
# [946]	validation-rmse:6.31069
# [947]	validation-rmse:6.31076
# [948]	validation-rmse:6.31077
# [949]	validation-rmse:6.31085
# [950]	validation-rmse:6.31078
# [951]	validation-rmse:6.31071
# [952]	validation-rmse:6.31073
# [953]	validation-rmse:6.31078
# [954]	validation-rmse:6.31062
# [955]	validation-rmse:6.31065
# [956]	validation-rmse:6.31065
# [957]	validation-rmse:6.31053
# [958]	validation-rmse:6.31054
# [959]	validation-rmse:6.31047
# [960]	validation-rmse:6.31052
# [961]	validation-rmse:6.31046
# [962]	validation-rmse:6.31048
# [963]	validation-rmse:6.31043
# [964]	validation-rmse:6.31043
# [965]	validation-rmse:6.31044
# [966]	validation-rmse:6.31045
# [967]	validation-rmse:6.31045
# [968]	validation-rmse:6.31035
# [969]	validation-rmse:6.31032
# [970]	validation-rmse:6.31029
# [971]	validation-rmse:6.31031
# [972]	validation-rmse:6.31025
# [973]	validation-rmse:6.31022
# [974]	validation-rmse:6.31025
# [975]	validation-rmse:6.31019
# [976]	validation-rmse:6.31017
# [977]	validation-rmse:6.31010
# [978]	validation-rmse:6.31004
# [979]	validation-rmse:6.31005
# [980]	validation-rmse:6.31008
# [981]	validation-rmse:6.31007
# [982]	validation-rmse:6.31008
# [983]	validation-rmse:6.31009
# [984]	validation-rmse:6.31015
# [985]	validation-rmse:6.31014
# [986]	validation-rmse:6.31034
# [987]	validation-rmse:6.31036
# [988]	validation-rmse:6.31040
# [989]	validation-rmse:6.31040
# [990]	validation-rmse:6.31047
# [991]	validation-rmse:6.31029
# [992]	validation-rmse:6.31024
# [993]	validation-rmse:6.31018
# [994]	validation-rmse:6.31016
# [995]	validation-rmse:6.31011
# [996]	validation-rmse:6.31010
# [997]	validation-rmse:6.30998
# [998]	validation-rmse:6.30993
# [999]	validation-rmse:6.30997
# /home/codespace/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# /home/codespace/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [13:07:56] WARNING: /workspace/src/c_api/c_api.cc:1374: Saving model in the UBJSON format as default.  You can use file extension: `json`, `ubj` or `deprecated` to choose between formats.
#   warnings.warn(smsg, UserWarning)

# %%
logged_model = "runs:/3545158565b946f399a4d65886d3a71f/models_mlflow"
loaded_model = mlflow.pyfunc.load_model(logged_model)

# %%
xgboost_model = mlflow.xgboost.load_model("runs:/3545158565b946f399a4d65886d3a71f/models_mlflow")

# %%
y_pred = xgboost_model.predict(valid)

# %%
y_pred[:10]
# Out:
# array([14.450237,  6.998118, 15.637997, 24.363546,  9.460321, 17.118723,
#        10.913568,  8.458502,  8.984916, 19.83681 ], dtype=float32)
